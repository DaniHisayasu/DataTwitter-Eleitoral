# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniHisayasu/DataTwitter-Eleitoral/blob/main/Etapa_2_Coleta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Apresentação do Projeto

# %% [markdown]
# Instalando bibliotecas

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %% [markdown]
# Importando as bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

#Manipulação de dados 
import pandas as pd

# %%
maximo_de_tweets = 50

# %% [markdown]
# ###Lula

# %%
lista_de_tweets_lula = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['lula']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_lula.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_lula = pd.DataFrame(lista_de_tweets_lula, columns=['Data_Hora','IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 15:30:48+00:00  1553765126955753472
# 1 2022-07-31 15:30:47+00:00  1553765122526642176
# 2 2022-07-31 15:30:46+00:00  1553765120274202628
# 3 2022-07-31 15:30:45+00:00  1553765112795774978
# 4 2022-07-31 15:30:44+00:00  1553765108802879489
#
#                                                Tweet
# 0  E parte da população, ainda quer o marginal, L...
# 1  Quais os desafios do próximo governo Lula, aul...
# 2  @geraldoalckmin @LulaOficial @PSBNacional40 @p...
# 3  @marciofrancasp @augustodeAB @JanainaDoBrasil ...
# 4  @LulaOficial @ricardostuckert A casa que vc ba...

# %%
dataframe_tweets_lula['Candidato']= 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 15:30:48+00:00  1553765126955753472
# 1 2022-07-31 15:30:47+00:00  1553765122526642176
# 2 2022-07-31 15:30:46+00:00  1553765120274202628
# 3 2022-07-31 15:30:45+00:00  1553765112795774978
# 4 2022-07-31 15:30:44+00:00  1553765108802879489
#
#                                                Tweet Candidato
# 0  E parte da população, ainda quer o marginal, L...      Lula
# 1  Quais os desafios do próximo governo Lula, aul...      Lula
# 2  @geraldoalckmin @LulaOficial @PSBNacional40 @p...      Lula
# 3  @marciofrancasp @augustodeAB @JanainaDoBrasil ...      Lula
# 4  @LulaOficial @ricardostuckert A casa que vc ba...      Lula

# %% [markdown]
# ###Bolsonaro

# %%
lista_de_tweets_bolsonaro = []

# %%
for i, tweet in enumerate (sntwitter.TwitterSearchScraper(['bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsoraro = pd.DataFrame(lista_de_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsoraro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsoraro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 15:30:51+00:00  1553765138481684482
# 1 2022-07-31 15:30:51+00:00  1553765138364342273
# 2 2022-07-31 15:30:50+00:00  1553765136690814978
# 3 2022-07-31 15:30:50+00:00  1553765135751282689
# 4 2022-07-31 15:30:47+00:00  1553765124619571210
#
#                                                Tweet  Candidato
# 0  @jairbolsonaro Canalha!\n\n#BolsonaroVagabundo...  Bolsonaro
# 1  : Assembleia dos rodoviários ontem em Recife. ...  Bolsonaro
# 2  Reza pai nosso com arma na mão?Bolsonaro e Min...  Bolsonaro
# 3  @jairbolsonaro @denise13duncan Valeu, Bonoro.\...  Bolsonaro
# 4              @RenataMaC2 @jairbolsonaro Que dó....  Bolsonaro

# %% [markdown]
# ###Ciro

# %%
lista_de_tweets_ciro = []

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['ciro']).get_items()):
  if i > maximo_de_tweets:
    break
  lista_de_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(lista_de_tweets_ciro, columns=['Data_Hora', 'IdTweet', "Tweet"])

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 15:30:43+00:00  1553765106617565184
# 1 2022-07-31 15:30:37+00:00  1553765079870590976
# 2 2022-07-31 15:30:36+00:00  1553765076095696902
# 3 2022-07-31 15:30:33+00:00  1553765063730798593
# 4 2022-07-31 15:30:18+00:00  1553765002145841153
#
#                                                Tweet Candidato
# 0                         @AcervoCharts e o ciro ac?      Ciro
# 1  Traíra,  quem vota nesses safados?? @ArthurLir...      Ciro
# 2  @desmentindobozo @ciro_nogueira Eu tenho curio...      Ciro
# 3  @anisio_nogueira @CiroNoFlow o pavor de vocês ...      Ciro
# 4  @LeonardoBoff O Ciro saiu do PDS mas o PDS não...      Ciro

# %%
dataframe_final = pd.concat([dataframe_tweets_ciro, dataframe_tweets_bolsoraro, dataframe_tweets_lula], axis = 0)

# %%
dataframe_final.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-07-31 15:30:43+00:00  1553765106617565184
# 1 2022-07-31 15:30:37+00:00  1553765079870590976
# 2 2022-07-31 15:30:36+00:00  1553765076095696902
# 3 2022-07-31 15:30:33+00:00  1553765063730798593
# 4 2022-07-31 15:30:18+00:00  1553765002145841153
#
#                                                Tweet Candidato
# 0                         @AcervoCharts e o ciro ac?      Ciro
# 1  Traíra,  quem vota nesses safados?? @ArthurLir...      Ciro
# 2  @desmentindobozo @ciro_nogueira Eu tenho curio...      Ciro
# 3  @anisio_nogueira @CiroNoFlow o pavor de vocês ...      Ciro
# 4  @LeonardoBoff O Ciro saiu do PDS mas o PDS não...      Ciro

# %%
dataframe_final['Candidato'].unique()
# Out:
# array(['Ciro', 'Bolsonaro', 'Lula'], dtype=object)

# %%
dataframe_final.to_csv('dataframe_final_candidato.csv', sep=',', index = False)
